# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 1585   ham  I was wondering if it would be okay for you to...        NaN
# 5561   ham  Get me out of this dump heap. My mom decided t...        NaN
# 830   spam  U have a secret admirer. REVEAL who thinks U R...        NaN
# 4391   ham                     what are your new years plans?        NaN
# 1840   ham  Yeah. I got a list with only u and Joanna if I...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1585        NaN        NaN
# 5561        NaN        NaN
# 830         NaN        NaN
# 4391        NaN        NaN
# 1840        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.info() # some of the value are missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 cols
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 297    ham  Hurt me... Tease me... Make me cry... But in t...
# 832   spam  Dear Voucher Holder, To claim this weeks offer...
# 2983   ham  He said that he had a right giggle when he saw...
# 2683   ham  I'm okay. Chasing the dream. What's good. What...
# 1299   ham  Great to hear you are settling well. So what's...

# %%
# renaming the columns
df.rename(columns = {'v1' : 'target', 'v2' : 'text'}, inplace = True)
df.sample(5)
# Out:
#      target                                               text
# 1097    ham  Don't fret. I'll buy the ovulation test strips...
# 2437   spam  For ur chance to win å£250 cash every wk TXT: ...
# 2272    ham  Haha awesome, I've been to 4u a couple times. ...
# 572     ham                             Can you open the door?
# 3677   spam  Promotion Number: 8714714 - UR awarded a City ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target']) 
# ham assign to 0, spam assign to 1

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## 2. EDA (Exploratory Data Analysis)

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham', 'spam'], autopct="%0.2f")
plt.show()

# %%
# Data is imbalanced

# %%
# text preprocessing library
import nltk

# %%
# !pip install nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chunlingtan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# add another column to look at the number of characters of the text
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# add the column for number of words 
# using lamda function 
# using the text preprocessing library
df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
# add the column for number of sentences using lambda function and sentence tokenize 
df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.453279       1.947185
# std         58.236293    13.324793       1.362406
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# describe output for ham messages
df[df['target'] == 0][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.120903       1.799601
# std         56.358207    13.493725       1.278465
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# describe output for spam messages
df[df['target'] == 1][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.967841
# std         30.137753    7.008418       1.483201
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       8.000000

# %%
# from the result above you can clearly see that the spam message basically has the higher number of sentences
# num_words and also num_sentences

# plot the histogram
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'], color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'], color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue='target')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /var/folders/9d/gh1b88712ls8_52kt29w8ffw0000gn/T/ipykernel_27793/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ## 3. Data Preprocessing
# - Lower case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming (dance, dancing, dances, etc.)

# %%
def transform_text(text):
    text = text.lower() # convert into lower case
    text = nltk.word_tokenize(text) # split the word and store into list
    
    y = [] # the list store the word that is valid
    for i in text:
        if i.isalnum(): # only alphabet and numeric can be stored
            y.append(i)
            
    text = y[:]
    y.clear()
    
    # check the word that is meaningful
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
            
    return " ".join(y)

# %%
transform_text("I loved the YT lectures on Machine Learning. How about you?")
# Out:
# 'love yt lectur machin learn'

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chunlingtan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('dancing')
# Out:
# 'danc'

# %%
# example transformation text
transform_text(df['text'][0])
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
df['transform_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                     transform_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500, height=500, min_font_size=10, background_color = 'white')

# %%
# generate the most words appear in spam
spam_wc = wc.generate(df[df['target']==1]['transform_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15, 6))
plt.imshow(spam_wc)

# %%
# generate the most words appear in ham
ham_wc = wc.generate(df[df['target']==0]['transform_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15, 6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                     transform_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transform_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
sns.barplot(data=pd.DataFrame(Counter(spam_corpus).most_common(30)), x=0, y=1)
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transform_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35394

# %%
sns.barplot(data=pd.DataFrame(Counter(ham_corpus).most_common(30)), x=0, y=1)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## 4. Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features = 3000) # max features improve

# %%
X = tfidf.fit_transform(df['transform_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3001)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
# gaussian naive bayes
gnb.fit(X_train, y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.8907156673114119
# [[800  96]
#  [ 17 121]]
# 0.5576036866359447

# %%
# multinomial naive bayes
mnb.fit(X_train, y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9738878143133463
# [[890   6]
#  [ 21 117]]
# 0.9512195121951219

# %%
# bernoulli naive bayes
bnb.fit(X_train, y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# tfidf, mnb is the best (after testing)

# %%
# !pip install xgboost

# %%
# testing other models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50, random_state=2)
xgb = XGBClassifier(n_estimators=50, random_state=2)

# %%
clfs = {
    'SVC'      : svc,
    'KN'       : knc,
    'NB'       : mnb,
    'DT'       : dtc,
    'LR'       : lrc,
    'RF'       : rfc,
    'AdaBoost' : abc,
    'BgC'      : bc,
    'ETC'      : etc,
    'GBDT'     : gbdt,
    'xgb'      : xgb
}

# %%
# function for training different kind of model, return the model accuracy and precision
def train_classifier(clf, X_train, y_train, X_test, y_test):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    
    return accuracy, precision

# %%
# result of every model
accuracy_scores = []
precision_scores = []

for name, clf in clfs.items():
    
    current_accuracy, current_precision = train_classifier(clf, X_train, y_train, X_test, y_test)
    
    print("For", name)
    print("Accuracy - ", current_accuracy)
    print("Precision - ", current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# /Users/chunlingtan/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# For SVC
# Accuracy -  0.8665377176015474
# Precision -  0.0
# For KN
# Accuracy -  0.8858800773694391
# Precision -  0.8333333333333334
# For NB
# Accuracy -  0.9738878143133463
# Precision -  0.9512195121951219
# For DT
# Accuracy -  0.9439071566731141
# Precision -  0.8703703703703703
# For LR
# Accuracy -  0.965183752417795
# Precision -  0.9553571428571429
# For RF
# Accuracy -  0.9680851063829787
# Precision -  0.981651376146789
# For AdaBoost
# Accuracy -  0.9642166344294004
# Precision -  0.9316239316239316
# For BgC
# Accuracy -  0.9661508704061895
# Precision -  0.8992248062015504
# For ETC
# Accuracy -  0.9806576402321083
# Precision -  0.9758064516129032
# For GBDT
# ...

# %%
performance_df = pd.DataFrame({
    'Algorithm': clfs.keys(), 
    'Accuracy': accuracy_scores, 
    'Precision': precision_scores
}).sort_values('Accuracy', ascending = False) # sort accuracy in descending order

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 8        ETC  0.975822   0.982906
# 5         RF  0.973888   1.000000
# 0        SVC  0.972921   0.974138
# 10       xgb  0.972921   0.936508
# 6   AdaBoost  0.961315   0.945455
# 2         NB  0.959381   1.000000
# 7        BgC  0.958414   0.862595
# 4         LR  0.951644   0.940000
# 9       GBDT  0.951644   0.923077
# 3         DT  0.935203   0.838095
# 1         KN  0.900387   1.000000

# %%
performance_df = pd.DataFrame({
    'Algorithm': clfs.keys(), 
    'Accuracy': accuracy_scores, 
    'Precision': precision_scores
}).sort_values('Precision', ascending = False) # sort precision in descending order

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 1         KN  0.905222   1.000000
# 2         NB  0.970986   1.000000
# 5         RF  0.974855   0.982759
# 0        SVC  0.975822   0.974790
# 8        ETC  0.974855   0.974576
# 4         LR  0.958414   0.970297
# 6   AdaBoost  0.960348   0.929204
# 10       xgb  0.966151   0.925620
# 9       GBDT  0.947776   0.920000
# 7        BgC  0.957447   0.867188
# 3         DT  0.930368   0.836735

# %%
performance_df1 = pd.melt(performance_df, id_vars = 'Algorithm')

# %%
sns.catplot(x = 'Algorithm', 
            y = 'value', 
            hue = 'variable',
            data = performance_df1,
            kind = 'bar',
            height = 5)
plt.ylim(0.5, 1.0)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# # Model Improvement
# 1. Change the max_features parameter of TfIdf
# 2. Using MinMaxScaler (preprocessing)
# 3. Appending the num_character col to X

# %%
temp_df = pd.DataFrame({
    'Algorithm': clfs.keys(),
    'Accuracy_max_ft_3000': accuracy_scores,
    'Precision_max_ft_3000': precision_scores
})

# %%
performance_df.merge(temp_df, on = 'Algorithm')
# we can see the accuracy increase although a slightly decrease in precision
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  Precision_max_ft_3000
# 0         KN  0.905222   1.000000              0.905222               1.000000
# 1         NB  0.970986   1.000000              0.970986               1.000000
# 2         RF  0.974855   0.982759              0.974855               0.982759
# 3        SVC  0.975822   0.974790              0.975822               0.974790
# 4        ETC  0.974855   0.974576              0.974855               0.974576
# 5         LR  0.958414   0.970297              0.958414               0.970297
# 6   AdaBoost  0.960348   0.929204              0.960348               0.929204
# 7        xgb  0.966151   0.925620              0.966151               0.925620
# 8       GBDT  0.947776   0.920000              0.947776               0.920000
# 9        BgC  0.957447   0.867188              0.957447               0.867188
# 10        DT  0.930368   0.836735              0.930368               0.836735

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
temp_df = pd.DataFrame({
    'Algorithm': clfs.keys(),
    'Accuracy_scaling': accuracy_scores,
    'Precision_scaling': precision_scores
})

# %%
new_df = performance_df.merge(temp_df, on='Algorithm')

# %%
new_df_scaled = new_df.merge(temp_df, on='Algorithm')

# %%
# appending the num_character col to X
X = np.hstack((X,df['num_characters'].values.reshape(-1,1)))

# %%
temp_df = pd.DataFrame({
    'Algorithm': clfs.keys(),
    'Accuracy_num_chars': accuracy_scores,
    'Precision_num_chars': precision_scores
})

# %%
new_df_scaled.merge(temp_df, on = 'Algorithm')
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling_x  Precision_scaling_x  \
# 0         KN  0.905222   1.000000            0.905222             1.000000
# 1         NB  0.970986   1.000000            0.970986             1.000000
# 2         RF  0.974855   0.982759            0.974855             0.982759
# 3        SVC  0.975822   0.974790            0.975822             0.974790
# 4        ETC  0.974855   0.974576            0.974855             0.974576
# 5         LR  0.958414   0.970297            0.958414             0.970297
# 6   AdaBoost  0.960348   0.929204            0.960348             0.929204
# 7        xgb  0.966151   0.925620            0.966151             0.925620
# 8       GBDT  0.947776   0.920000            0.947776             0.920000
# 9        BgC  0.957447   0.867188            0.957447             0.867188
# 10        DT  0.930368   0.836735            0.930368             0.836735
#
#     Accuracy_scaling_y  Precision_scaling_y  Accuracy_num_chars  \
# ...

# %% [markdown]
# # Voting Classifier
# Based on the result above, we choose svc, mnb and etc. Therefore we choose to use these three models to create voting classifier.
#
#
# ## Definition
# A Voting Classifier is a machine learning model that trains on an ensemble of numerous models and predicts an output (class) based on their highest probability of chosen class as the output. It simply aggregates the findings of each classifier passed into Voting Classifier and predicts the output class based on the highest majority of voting.
# ![image.png](attachment:193b171f-2bb5-48de-99f3-6db67e89a62a.png)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(
    estimators =[('svm', svc), 
                ('nb', mnb), 
                ('et', etc)],
    voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9738878143133463
# Precision 1.0

# %% [markdown]
# # Applying Stacking
